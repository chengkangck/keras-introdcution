# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
x_data = np.random.rand(100)
noise = np.random.normal(0, 0.01, x_data.shape)
y_data = 0.1*x_data + 0.2 + noise

# %%
plt.scatter(x_data, y_data)
plt.show()

# %%
model = Sequential()
model.add(Dense(1, input_shape=(1,)))
model.compile(optimizer=SGD(), loss="MSE")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0128 16:37:47.637291  7684 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0128 16:37:47.711600  7684 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0128 16:37:47.722802  7684 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0128 16:37:47.792766  7684 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
for i in range(6000):
    cost = model.train_on_batch(x_data, y_data)
    if i % 500 == 0:
        print('step:', i, '    cost:', cost)
# Out:
# W0128 16:40:22.334811  7684 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0128 16:40:22.389097  7684 deprecation_wrapper.py:119] From D:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# step: 0     cost: 0.33308682
# step: 500     cost: 0.004609938
# step: 1000     cost: 0.0012188918
# step: 1500     cost: 0.00037404418
# step: 2000     cost: 0.00016355878
# step: 2500     cost: 0.00011111822
# step: 3000     cost: 9.805327e-05
# step: 3500     cost: 9.479823e-05
# step: 4000     cost: 9.3987306e-05
# step: 4500     cost: 9.378524e-05
# step: 5000     cost: 9.3734925e-05
# step: 5500     cost: 9.372236e-05

# %%
W, b = model.layers[0].get_weights()
print(W, b)
# Out:
# [[0.09587958]] [0.20218588]

# %%
y_pred = model.predict(x_data)
plt.scatter(x_data, y_data)
plt.plot(x_data, y_pred, 'r-', lw=3)
plt.show()

# %%
x_data = np.linspace(-1, 1, 200)
noise = np.random.normal(0, 0.1, x_data.shape)
y_data = np.square(x_data) + noise

# %%
plt.scatter(x_data, y_data)
plt.show()

# %%
model = Sequential()
model.add(Dense(5, input_shape=(1,), activation='tanh'))
model.add(Dense(1))
model.compile(optimizer=SGD(), loss="MSE")

# %%
for i in range(6000):
    cost = model.train_on_batch(x_data, y_data)
    if i % 500 == 0:
        print('step:', i, '    cost:', cost)


W, b = model.layers[0].get_weights()
print(W, b)
# Out:
# step: 0     cost: 0.22268093
# step: 500     cost: 0.08805987
# step: 1000     cost: 0.06912712
# step: 1500     cost: 0.050125033
# step: 2000     cost: 0.03407601
# step: 2500     cost: 0.02323673
# step: 3000     cost: 0.01736171
# step: 3500     cost: 0.014699892
# step: 4000     cost: 0.013618451
# step: 4500     cost: 0.013181901
# step: 5000     cost: 0.012979423
# step: 5500     cost: 0.012856935
# [[-0.36165008  1.6141174  -0.35340452 -0.8001288  -0.9519598 ]] [ 0.12957723 -0.90966547  0.2646528   0.04979778 -0.3974573 ]

# %%
y_pred = model.predict(x_data)
plt.scatter(x_data, y_data)
plt.plot(x_data, y_pred, 'r-', lw=3)
plt.show()
